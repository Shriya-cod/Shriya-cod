# %% [markdown]
# <a href="https://colab.research.google.com/github/Shriya-cod/Shriya-cod/blob/main/student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3

# %matplotlib inline

# %%
df = pd.read_csv('StudentsPerformance.csv')

# %%
conn = sqlite3.connect(':memory:')
df.to_sql("Students", conn, index = False, if_exists = 'replace')
# Out:
# 1000

# %%
# Writing SQL queries

query = ('''SELECT * FROM Students''')
result = pd.read_sql_query(query, conn)
result
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
print(df.columns.to_list())
# Out:
# ['gender', 'race/ethnicity', 'parental level of education', 'lunch', 'test preparation course', 'math score', 'reading score', 'writing score']

# %%
df['reading score'].mean()
# Out:
# np.float64(69.169)

# %%
df['reading score'].plot(kind = 'box', vert = False, figsize = (10,3))
# Out:
# <Axes: >

# %%
ax = df['reading score'].plot(kind = 'density', figsize = (10,3))
ax.axvline(df['reading score'].mean(), color ='red')
ax.axvline(df['reading score'].median(), color = 'black')

# %%
ax = df['gender'].value_counts().plot(kind = 'bar', figsize = (10,3))
ax.set_ylabel('reading score')
# Out:
# Text(0, 0.5, 'reading score')

# %%
df['reading score'].plot(kind = 'hist', figsize = (10,3))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['parental level of education'].value_counts().plot(kind = 'pie', figsize = (3,3))
# Out:
# <Axes: ylabel='count'>

# %%
df.plot(kind = 'scatter', x = 'gender', y = 'reading score', figsize = (10,3))
# Out:
# <Axes: xlabel='gender', ylabel='reading score'>

# %%
df[['gender', 'parental level of education', 'reading score']].plot(kind = 'box', figsize = (10,3))
# Out:
# <Axes: >

# %%
df.groupby('gender')['reading score'].mean()
# Out:
# gender
# female    72.608108
# male      65.473029
# Name: reading score, dtype: float64

# %%
df.groupby('parental level of education')[['reading score', 'writing score']].mean()
# Out:
#                              reading score  writing score
# parental level of education
# associate's degree               70.927928      69.896396
# bachelor's degree                73.000000      73.381356
# high school                      64.704082      62.448980
# master's degree                  75.372881      75.677966
# some college                     69.460177      68.840708
# some high school                 66.938547      64.888268

# %%
df['reading score'].value_counts()
# Out:
# reading score
# 72    34
# 74    33
# 64    32
# 73    30
# 67    30
#       ..
# 32     1
# 26     1
# 28     1
# 23     1
# 40     1
# Name: count, Length: 72, dtype: int64
